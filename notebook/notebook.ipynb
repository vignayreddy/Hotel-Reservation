# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd

# %%
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Unnamed: 0 Booking_ID  ...  no_of_special_requests  booking_status
# 0       25629   INN25630  ...                       0    Not_Canceled
# 1       14473   INN14474  ...                       2    Not_Canceled
# 2       23720   INN23721  ...                       0        Canceled
# 3        5843   INN05844  ...                       0    Not_Canceled
# 4       18709   INN18710  ...                       0        Canceled
#
# [5 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Booking_ID', 'no_of_adults', 'no_of_children',
#        'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan',
#        'required_car_parking_space', 'room_type_reserved', 'lead_time',
#        'arrival_year', 'arrival_month', 'arrival_date', 'market_segment_type',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
df.drop(columns=["Booking_ID","Unnamed: 0"],inplace=True)
df.head()
# Out:
#    no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0             2               1  ...                       0    Not_Canceled
# 1             2               1  ...                       2    Not_Canceled
# 2             2               0  ...                       0        Canceled
# 3             2               0  ...                       0    Not_Canceled
# 4             1               0  ...                       0        Canceled
#
# [5 rows x 18 columns]

# %%
df.shape
# Out:
# (29020, 18)

# %%
df.isna().sum()
# Out:
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(7661)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (21359, 18)

# %%
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
df["no_of_adults"].value_counts()
# Out:
# no_of_adults
# 2    15489
# 1     3996
# 3     1748
# 0      113
# 4       13
# Name: count, dtype: int64

# %%
df["no_of_children"].value_counts()
# Out:
# no_of_children
# 0     19251
# 1      1257
# 2       837
# 3        11
# 9         2
# 10        1
# Name: count, dtype: int64

# %%
df["no_of_weekend_nights"].value_counts()
# Out:
# no_of_weekend_nights
# 0    9178
# 1    6063
# 2    5882
# 3     110
# 4      91
# 5      21
# 6      14
# Name: count, dtype: int64

# %%
df["no_of_week_nights"].value_counts()
# Out:
# no_of_week_nights
# 2     5894
# 1     5833
# 3     4628
# 4     1980
# 0     1492
# 5     1169
# 6      136
# 7       81
# 8       43
# 10      41
# 9       24
# 11      12
# 15       7
# 12       6
# 14       5
# 13       4
# 16       2
# 17       2
# Name: count, dtype: int64

# %%
df["type_of_meal_plan"].value_counts()
# Out:
# type_of_meal_plan
# Meal Plan 1     16759
# Not Selected     3627
# Meal Plan 2       969
# Meal Plan 3         4
# Name: count, dtype: int64

# %%
df["required_car_parking_space"].value_counts()
# Out:
# required_car_parking_space
# 0    20452
# 1      907
# Name: count, dtype: int64

# %%
df["room_type_reserved"].value_counts()
# Out:
# room_type_reserved
# Room_Type 1    15375
# Room_Type 4     4403
# Room_Type 6      758
# Room_Type 2      500
# Room_Type 5      190
# Room_Type 7      129
# Room_Type 3        4
# Name: count, dtype: int64

# %%
df["arrival_year"].value_counts()
# Out:
# arrival_year
# 2018    18141
# 2017     3218
# Name: count, dtype: int64

# %%
df["arrival_month"].value_counts()
# Out:
# arrival_month
# 10    2663
# 9     2525
# 8     2477
# 12    1928
# 7     1893
# 11    1817
# 4     1695
# 3     1611
# 6     1543
# 5     1522
# 2     1067
# 1      618
# Name: count, dtype: int64

# %%
df["market_segment_type"].value_counts()
# Out:
# market_segment_type
# Online           16324
# Offline           3471
# Corporate         1192
# Complementary      291
# Aviation            81
# Name: count, dtype: int64

# %%
df["repeated_guest"].value_counts()
# Out:
# repeated_guest
# 0    20667
# 1      692
# Name: count, dtype: int64

# %%
df["no_of_previous_cancellations"].value_counts()
# Out:
# no_of_previous_cancellations
# 0     21135
# 1       115
# 2        36
# 3        32
# 11       20
# 5        10
# 4         9
# 13        1
# 6         1
# Name: count, dtype: int64

# %%
df["booking_status"].value_counts()
# Out:
# booking_status
# Not_Canceled    15231
# Canceled         6128
# Name: count, dtype: int64

# %% [markdown]
# ### Our data is imbalanced

# %%
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
cat_cols = ['type_of_meal_plan','required_car_parking_space',
       'room_type_reserved','market_segment_type', 'repeated_guest','booking_status']

num_cols = ['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights','lead_time', 'arrival_year', 'arrival_month',
       'arrival_date','no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
       'avg_price_per_room', 'no_of_special_requests']

# %% [markdown]
# ## Data Analysis

# %%
data = df.copy()

# %%
data.head()
# Out:
#    no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0             2               1  ...                       0    Not_Canceled
# 1             2               1  ...                       2    Not_Canceled
# 2             2               0  ...                       0        Canceled
# 3             2               0  ...                       0    Not_Canceled
# 4             1               0  ...                       0        Canceled
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Univariate Analysis

# %%
def num_plot_dist(df , num_features):
    fig , axes = plt.subplots(len(num_features),2,figsize=(15,len(num_features)*5))
    if len(num_features)==1:
        axes=[axes]
    
    for i,column in enumerate(num_features):
        sns.histplot(data=df , x=column , ax=axes[i][0] , kde=True , palette="Blues" )
        axes[i][0].set_title(f"Histogram for {column}")

        sns.boxplot(data=df , x=column , ax=axes[i][1] , palette="Blues")
        axes[i][1].set_title(f"Box Plot for {column}")
    
    plt.tight_layout() #Kernel Density Estimation
    plt.show()

# %%
num_plot_dist(data , num_cols)

# %%
for cat_feature in cat_cols:
    plt.figure(figsize=(10,6))
    print(data[cat_feature].value_counts())
    data[cat_feature].value_counts().plot(kind="bar",color="green")
    plt.title(f"{cat_feature} Distribution")
    plt.xlabel(cat_feature)
    plt.ylabel("Count")
    plt.show()
# Out:
# type_of_meal_plan
# Meal Plan 1     16759
# Not Selected     3627
# Meal Plan 2       969
# Meal Plan 3         4
# Name: count, dtype: int64
# required_car_parking_space
# 0    20452
# 1      907
# Name: count, dtype: int64
# room_type_reserved
# Room_Type 1    15375
# Room_Type 4     4403
# Room_Type 6      758
# Room_Type 2      500
# Room_Type 5      190
# Room_Type 7      129
# Room_Type 3        4
# Name: count, dtype: int64
# market_segment_type
# Online           16324
# Offline           3471
# Corporate         1192
# Complementary      291
# Aviation            81
# Name: count, dtype: int64
# repeated_guest
# 0    20667
# 1      692
# Name: count, dtype: int64
# booking_status
# Not_Canceled    15231
# Canceled         6128
# Name: count, dtype: int64

# %% [markdown]
# ## Bivariate Analysis

# %%
def plot_bivariate_num(df , target , num_features):
    num_plots = len(num_features)
    num_rows = (num_plots+1)//2

    fig , axes = plt.subplots(num_rows , 2 , figsize=(15 , num_rows*5))
    axes = axes.flatten()

    for i , column in enumerate(num_features):
        sns.boxplot(x=target,y=column,ax=axes[i] , data=df , palette="Blues")
        axes[i].set_title(f"{column}  VS {target}")

    plt.tight_layout()
    plt.show()

# %%
plot_bivariate_num(data , 'booking_status' , num_cols)

# %%
sns.barplot(x="arrival_month",y="avg_price_per_room",data=data)
plt.show()

# %%
def plot_bivariate_cat(df,target,cat_features):
    num_features = len(cat_features)
    num_rows = (num_features+1)//2

    fig , axes = plt.subplots(num_rows , 2 , figsize=(15 , num_rows*5))
    axes = axes.flatten()

    for i,feature in enumerate(cat_cols):
        sns.countplot(x=feature,hue=target,data=df,palette="Set2",ax=axes[i])
        axes[i].set_title(f"{feature} VS {target}")
    
    plt.tight_layout()
    plt.show()

# %%
plot_bivariate_cat(df,"booking_status",cat_cols)

# %% [markdown]
# ## Data Processing

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0             2               1  ...                       0    Not_Canceled
# 1             2               1  ...                       2    Not_Canceled
# 2             2               0  ...                       0        Canceled
# 3             2               0  ...                       0    Not_Canceled
# 4             1               0  ...                       0        Canceled
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21359 entries, 0 to 29019
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          21359 non-null  int64
#  1   no_of_children                        21359 non-null  int64
#  2   no_of_weekend_nights                  21359 non-null  int64
#  3   no_of_week_nights                     21359 non-null  int64
#  4   type_of_meal_plan                     21359 non-null  object
#  5   required_car_parking_space            21359 non-null  int64
#  6   room_type_reserved                    21359 non-null  object
#  7   lead_time                             21359 non-null  int64
#  8   arrival_year                          21359 non-null  int64
#  9   arrival_month                         21359 non-null  int64
#  10  arrival_date                          21359 non-null  int64
#  11  market_segment_type                   21359 non-null  object
#  12  repeated_guest                        21359 non-null  int64
#  13  no_of_previous_cancellations          21359 non-null  int64
#  14  no_of_previous_bookings_not_canceled  21359 non-null  int64
#  15  avg_price_per_room                    21359 non-null  float64
#  16  no_of_special_requests                21359 non-null  int64
#  17  booking_status                        21359 non-null  object
# dtypes: float64(1), int64(13), object(4)
# memory usage: 3.1+ MB

# %%
##### Label Encoding
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

mappings = {}
for col in df.select_dtypes(include='object').columns:
    df[col]=label_encoder.fit_transform(df[col])

    mappings[col]={label:code for label,code in zip(label_encoder.classes_,label_encoder.transform(label_encoder.classes_))}
    print(mappings)
# Out:
# {'type_of_meal_plan': {'Meal Plan 1': np.int64(0), 'Meal Plan 2': np.int64(1), 'Meal Plan 3': np.int64(2), 'Not Selected': np.int64(3)}}
# {'type_of_meal_plan': {'Meal Plan 1': np.int64(0), 'Meal Plan 2': np.int64(1), 'Meal Plan 3': np.int64(2), 'Not Selected': np.int64(3)}, 'room_type_reserved': {'Room_Type 1': np.int64(0), 'Room_Type 2': np.int64(1), 'Room_Type 3': np.int64(2), 'Room_Type 4': np.int64(3), 'Room_Type 5': np.int64(4), 'Room_Type 6': np.int64(5), 'Room_Type 7': np.int64(6)}}
# {'type_of_meal_plan': {'Meal Plan 1': np.int64(0), 'Meal Plan 2': np.int64(1), 'Meal Plan 3': np.int64(2), 'Not Selected': np.int64(3)}, 'room_type_reserved': {'Room_Type 1': np.int64(0), 'Room_Type 2': np.int64(1), 'Room_Type 3': np.int64(2), 'Room_Type 4': np.int64(3), 'Room_Type 5': np.int64(4), 'Room_Type 6': np.int64(5), 'Room_Type 7': np.int64(6)}, 'market_segment_type': {'Aviation': np.int64(0), 'Complementary': np.int64(1), 'Corporate': np.int64(2), 'Offline': np.int64(3), 'Online': np.int64(4)}}
# {'type_of_meal_plan': {'Meal Plan 1': np.int64(0), 'Meal Plan 2': np.int64(1), 'Meal Plan 3': np.int64(2), 'Not Selected': np.int64(3)}, 'room_type_reserved': {'Room_Type 1': np.int64(0), 'Room_Type 2': np.int64(1), 'Room_Type 3': np.int64(2), 'Room_Type 4': np.int64(3), 'Room_Type 5': np.int64(4), 'Room_Type 6': np.int64(5), 'Room_Type 7': np.int64(6)}, 'market_segment_type': {'Aviation': np.int64(0), 'Complementary': np.int64(1), 'Corporate': np.int64(2), 'Offline': np.int64(3), 'Online': np.int64(4)}, 'booking_status': {'Canceled': np.int64(0), 'Not_Canceled': np.int64(1)}}

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0             2               1  ...                       0               1
# 1             2               1  ...                       2               1
# 2             2               0  ...                       0               0
# 3             2               0  ...                       0               1
# 4             1               0  ...                       0               0
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21359 entries, 0 to 29019
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          21359 non-null  int64
#  1   no_of_children                        21359 non-null  int64
#  2   no_of_weekend_nights                  21359 non-null  int64
#  3   no_of_week_nights                     21359 non-null  int64
#  4   type_of_meal_plan                     21359 non-null  int64
#  5   required_car_parking_space            21359 non-null  int64
#  6   room_type_reserved                    21359 non-null  int64
#  7   lead_time                             21359 non-null  int64
#  8   arrival_year                          21359 non-null  int64
#  9   arrival_month                         21359 non-null  int64
#  10  arrival_date                          21359 non-null  int64
#  11  market_segment_type                   21359 non-null  int64
#  12  repeated_guest                        21359 non-null  int64
#  13  no_of_previous_cancellations          21359 non-null  int64
#  14  no_of_previous_bookings_not_canceled  21359 non-null  int64
#  15  avg_price_per_room                    21359 non-null  float64
#  16  no_of_special_requests                21359 non-null  int64
#  17  booking_status                        21359 non-null  int64
# dtypes: float64(1), int64(17)
# memory usage: 3.1 MB

# %%
### Multicollinearity
# Variance Inflation Factor (VIF): whether mc is present or not
# %pip install statsmodels


##Above 5 much multicollinearity
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
X = add_constant(df)

vif_data = pd.DataFrame()

vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif_data
# Out:
#                                  feature           VIF
# 0                                  const  4.100197e+07
# 1                           no_of_adults  1.341180e+00
# 2                         no_of_children  1.282459e+00
# 3                   no_of_weekend_nights  1.073215e+00
# 4                      no_of_week_nights  1.125260e+00
# 5                      type_of_meal_plan  1.178228e+00
# 6             required_car_parking_space  1.036105e+00
# 7                     room_type_reserved  1.549859e+00
# 8                              lead_time  1.406287e+00
# 9                           arrival_year  1.288533e+00
# 10                         arrival_month  1.248028e+00
# 11                          arrival_date  1.003605e+00
# 12                   market_segment_type  1.704297e+00
# 13                        repeated_guest  1.765576e+00
# 14          no_of_previous_cancellations  1.396559e+00
# 15  no_of_previous_bookings_not_canceled  1.712854e+00
# 16                    avg_price_per_room  1.926372e+00
# 17                no_of_special_requests  1.267940e+00
# 18                        booking_status  1.389308e+00

# %% [markdown]
# ### Our data doesnt have much collinearity

# %%
d1=df.corr()
d1
# Out:
#                                       no_of_adults  ...  booking_status
# no_of_adults                              1.000000  ...       -0.097198
# no_of_children                           -0.049738  ...       -0.060030
# no_of_weekend_nights                      0.092764  ...       -0.067944
# no_of_week_nights                         0.114218  ...       -0.124415
# type_of_meal_plan                        -0.005977  ...       -0.035864
# required_car_parking_space                0.000419  ...        0.092511
# room_type_reserved                        0.275089  ...       -0.072128
# lead_time                                 0.150995  ...       -0.368151
# arrival_year                              0.096366  ...       -0.149673
# arrival_month                             0.004833  ...        0.015898
# arrival_date                              0.018382  ...       -0.014955
# market_segment_type                       0.310783  ...       -0.196296
# repeated_guest                           -0.238974  ...        0.111390
# no_of_previous_cancellations             -0.063739  ...        0.038710
# no_of_previous_bookings_not_canceled     -0.143903  ...        0.063052
# avg_price_per_room                        0.327749  ...       -0.155690
# no_of_special_requests                    0.156833  ...        0.261191
# booking_status                           -0.097198  ...        1.000000
#
# [18 rows x 18 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
### Skewness
skewness = df.skew()
skewness
# Out:
# no_of_adults                            -0.305652
# no_of_children                           4.165696
# no_of_weekend_nights                     0.636637
# no_of_week_nights                        1.553657
# type_of_meal_plan                        1.650716
# required_car_parking_space               4.538315
# room_type_reserved                       1.392145
# lead_time                                1.405258
# arrival_year                            -1.953273
# arrival_month                           -0.293266
# arrival_date                             0.010333
# market_segment_type                     -2.333046
# repeated_guest                           5.282330
# no_of_previous_cancellations            22.001489
# no_of_previous_bookings_not_canceled    16.735934
# avg_price_per_room                       0.542888
# no_of_special_requests                   0.922373
# booking_status                          -0.942305
# dtype: float64

# %%
for col in df.columns:
    if skewness[col]>5:
        df[col]=np.log1p(df[col])
skewness = df.skew()
skewness
# Out:
# no_of_adults                            -0.305652
# no_of_children                           4.165696
# no_of_weekend_nights                     0.636637
# no_of_week_nights                        1.553657
# type_of_meal_plan                        1.650716
# required_car_parking_space               4.538315
# room_type_reserved                       1.392145
# lead_time                                1.405258
# arrival_year                            -1.953273
# arrival_month                           -0.293266
# arrival_date                             0.010333
# market_segment_type                     -2.333046
# repeated_guest                           5.282330
# no_of_previous_cancellations            13.270580
# no_of_previous_bookings_not_canceled     7.619850
# avg_price_per_room                       0.542888
# no_of_special_requests                   0.922373
# booking_status                          -0.942305
# dtype: float64

# %%
x= df.drop(columns="booking_status")
y = df["booking_status"]

x.columns
y.value_counts()
# Out:
# booking_status
# 1    15231
# 0     6128
# Name: count, dtype: int64

# %%
# %pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in c:\programdata\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

X_res,y_res = smote.fit_resample(x,y)

# %%
X_res
# Out:
#        no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 0                 2               1  ...          161.000000                       0
# 1                 2               1  ...          121.500000                       2
# 2                 2               0  ...           70.000000                       0
# 3                 2               0  ...           72.250000                       0
# 4                 1               0  ...          130.000000                       0
# ...             ...             ...  ...                 ...                     ...
# 30457             2               0  ...          111.037207                       0
# 30458             1               0  ...           72.250000                       0
# 30459             2               0  ...          104.556265                       0
# 30460             1               0  ...          107.100000                       0
# 30461             2               0  ...          135.000000                       0
#
# [30462 rows x 17 columns]

# %%
y_res.value_counts()
# Out:
# booking_status
# 1    15231
# 0    15231
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (21359, 18)

# %%
balanced_df = pd.DataFrame(X_res,columns=x.columns)
balanced_df["booking_status"]=y_res
balanced_df.shape
# Out:
# (30462, 18)

# %%
balanced_df
# Out:
#        no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0                 2               1  ...                       0               1
# 1                 2               1  ...                       2               1
# 2                 2               0  ...                       0               0
# 3                 2               0  ...                       0               1
# 4                 1               0  ...                       0               0
# ...             ...             ...  ...                     ...             ...
# 30457             2               0  ...                       0               0
# 30458             1               0  ...                       0               0
# 30459             2               0  ...                       0               0
# 30460             1               0  ...                       0               0
# 30461             2               0  ...                       0               0
#
# [30462 rows x 18 columns]

# %%
df = balanced_df.copy()
df.head()
# Out:
#    no_of_adults  no_of_children  ...  no_of_special_requests  booking_status
# 0             2               1  ...                       0               1
# 1             2               1  ...                       2               1
# 2             2               0  ...                       0               0
# 3             2               0  ...                       0               1
# 4             1               0  ...                       0               0
#
# [5 rows x 18 columns]

# %%
df.shape
# Out:
# (30462, 18)

# %% [markdown]
# #### Feature Selection

# %%
len(df.columns)
# Out:
# 18

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x = df.drop(columns='booking_status')
y = df["booking_status"]

# %%
model = RandomForestClassifier(random_state=42)
model.fit(x,y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importance = model.feature_importances_
feature_importance_df = pd.DataFrame({"feature":x.columns,
                                   "importance":feature_importance
                })
feature_importance_df
# Out:
#                                  feature  importance
# 0                           no_of_adults    0.018026
# 1                         no_of_children    0.006913
# 2                   no_of_weekend_nights    0.029981
# 3                      no_of_week_nights    0.043996
# 4                      type_of_meal_plan    0.020269
# 5             required_car_parking_space    0.011561
# 6                     room_type_reserved    0.019697
# 7                              lead_time    0.261824
# 8                           arrival_year    0.016407
# 9                          arrival_month    0.086209
# 10                          arrival_date    0.084072
# 11                   market_segment_type    0.058509
# 12                        repeated_guest    0.006886
# 13          no_of_previous_cancellations    0.000364
# 14  no_of_previous_bookings_not_canceled    0.002614
# 15                    avg_price_per_room    0.150638
# 16                no_of_special_requests    0.182032

# %%
top_features_importance_df = feature_importance_df.sort_values(by="importance",ascending=False)
top_features_importance_df
# Out:
#                                  feature  importance
# 7                              lead_time    0.261824
# 16                no_of_special_requests    0.182032
# 15                    avg_price_per_room    0.150638
# 9                          arrival_month    0.086209
# 10                          arrival_date    0.084072
# 11                   market_segment_type    0.058509
# 3                      no_of_week_nights    0.043996
# 2                   no_of_weekend_nights    0.029981
# 4                      type_of_meal_plan    0.020269
# 6                     room_type_reserved    0.019697
# 0                           no_of_adults    0.018026
# 8                           arrival_year    0.016407
# 5             required_car_parking_space    0.011561
# 1                         no_of_children    0.006913
# 12                        repeated_guest    0.006886
# 14  no_of_previous_bookings_not_canceled    0.002614
# 13          no_of_previous_cancellations    0.000364

# %%
len(df.columns)
# Out:
# 18

# %%
top_10_features = top_features_importance_df["feature"].head(10).values
top_10_df = df[top_10_features.tolist()+["booking_status"]]
top_10_df
# Out:
#        lead_time  no_of_special_requests  ...  room_type_reserved  booking_status
# 0             26                       0  ...                   0               1
# 1             98                       2  ...                   0               1
# 2            433                       0  ...                   0               0
# 3            195                       0  ...                   0               1
# 4            188                       0  ...                   0               0
# ...          ...                     ...  ...                 ...             ...
# 30457        265                       0  ...                   0               0
# 30458        103                       0  ...                   0               0
# 30459         27                       0  ...                   0               0
# 30460         46                       0  ...                   0               0
# 30461         12                       0  ...                   0               0
#
# [30462 rows x 11 columns]

# %%
df = top_10_df.copy()
df.head()
# Out:
#    lead_time  no_of_special_requests  ...  room_type_reserved  booking_status
# 0         26                       0  ...                   0               1
# 1         98                       2  ...                   0               1
# 2        433                       0  ...                   0               0
# 3        195                       0  ...                   0               1
# 4        188                       0  ...                   0               0
#
# [5 rows x 11 columns]

# %%
df.shape
# Out:
# (30462, 11)

# %% [markdown]
# ## Model Selection

# %%
# %pip install xgboost lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\vigna\appdata\roaming\python\python313\site-packages (3.1.1)
# Requirement already satisfied: lightgbm in c:\users\vigna\appdata\roaming\python\python313\site-packages (4.6.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import  LGBMClassifier

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
x = df.drop(columns="booking_status")
y = df["booking_status"]

# %%
x_train, x_test , y_train,y_test  = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
classifiers = {
    "Random Forest" : RandomForestClassifier(random_state=42),
    "LogisticRegression" : LogisticRegression(random_state=42),
    "Gradient Boosting" : GradientBoostingClassifier(random_state=42),
    "Suuport vector classifier" : SVC(random_state=42),
    "Decsion Tree" : DecisionTreeClassifier(random_state=42),
    "KNN" : KNeighborsClassifier(),
    "Naive Bayes" : GaussianNB(),
    "XGboost" : XGBClassifier(random_state=42),
    "Adaboost" : AdaBoostClassifier(random_state=42),
    "LGBM" : LGBMClassifier(random_state=42) 
}

# %%
metrics = {
    "Model" : [],
    "Accuracy" : [],
    "Precision" : [],
    "Recall" : [],
    "F1 Score" : []
}

# %%
for model_name,classifier in classifiers.items():
    classifier.fit(x_train,y_train)

    y_pred = classifier.predict(x_test)

    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)

    metrics["Model"].append(model_name)
    metrics["Accuracy"].append(accuracy)
    metrics["Precision"].append(precision)
    metrics["Recall"].append(recall)
    metrics["F1 Score"].append(f1)
metrics_df= pd.DataFrame(metrics)
metrics_df
# Out:
# [LightGBM] [Info] Number of positive: 12161, number of negative: 12208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 601
# [LightGBM] [Info] Number of data points in the train set: 24369, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499036 -> initscore=-0.003857
# [LightGBM] [Info] Start training from score -0.003857
#                        Model  Accuracy  Precision    Recall  F1 Score
# 0              Random Forest  0.891351   0.893721  0.890228  0.891971
# 1         LogisticRegression  0.786312   0.804408  0.760912  0.782056
# 2          Gradient Boosting  0.838175   0.819632  0.870358  0.844234
# 3  Suuport vector classifier  0.720335   0.729657  0.706840  0.718068
# 4               Decsion Tree  0.836534   0.845667  0.826384  0.835914
# 5                        KNN  0.779255   0.856258  0.675244  0.755054
# 6                Naive Bayes  0.773182   0.803161  0.728339  0.763922
# 7                    XGboost  0.874610   0.870978  0.881759  0.876335
# 8                   Adaboost  0.804530   0.801025  0.814332  0.807624
# 9                       LGBM  0.866076   0.851309  0.889577  0.870022

# %%
#### TRAIN OUR RANDOMFOREST MODEL
from sklearn.model_selection import RandomizedSearchCV,train_test_split
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint

# %%
x = df.drop(columns="booking_status")
y = df["booking_status"]

# %%
x_train, x_test , y_train,y_test  = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
rf = RandomForestClassifier(random_state=42)
params_dist={
    "n_estimators":randint(100,500),
    "max_depth":randint(5,20),
    "min_samples_split":randint(2,10),
    "min_samples_leaf":randint(1,10),
    "bootstrap":[True,False]

}

# %%
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=params_dist,
    n_iter=5,
    cv=5,
    verbose=2,
    random_state=42,
    scoring='accuracy'
)

# %%
random_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=8, min_samples_split=6, n_estimators=120; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=8, min_samples_split=6, n_estimators=120; total time=   1.7s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=8, min_samples_split=6, n_estimators=120; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=8, min_samples_split=6, n_estimators=120; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=8, min_samples_split=6, n_estimators=120; total time=   2.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=  13.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=  14.1s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=  20.1s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=  10.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=  20.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   9.6s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   9.3s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=  11.4s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=  10.8s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=  12.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=   9.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=  10.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=   9.3s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=   7.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=   5.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=  14.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=  10.2s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=  10.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=  13.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=  10.4s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=5,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001590BA42C30>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001590B912AD0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001590B9128B0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001596CA03CE0>},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
random_search.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 16,
#  'min_samples_leaf': 6,
#  'min_samples_split': 3,
#  'n_estimators': 291}

# %%
best_rf_model = random_search.best_estimator_

# %%
y_pred = best_rf_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)

# %%
f1
# Out:
# 0.8765156349712827

# %%
accuracy
# Out:
# 0.8729689807976366

# %%
precision
# Out:
# 0.8589743589743589

# %%
recall
# Out:
# 0.8947882736156352

# %%
### Save this model

# %%
import joblib

# %%
joblib.dump(best_rf_model,"random_forest.pkl")
# Out:
# ['random_forest.pkl']

# %%
loaded_model=joblib.load("random_forest.pkl")

# %%
x_train[0:1]
new_data = np.array([190,1 ,	93.5,	9	,8,	4,	5,	2,	0,	0]).reshape(1,-1)

# %%
predictions=loaded_model.predict(new_data)

# %%
predictions[0]
# Out:
# np.int64(1)
